# %%
# !pip install -qq convokit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.2/183.2 kB 3.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 16.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 30.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 16.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 16.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 5.2 MB/s eta 0:00:00
#   Building wheel for convokit (pyproject.toml) ... done
#   Building wheel for emoji (setup.py) ... done

# %%
# !pip install -qq scikit-surprise
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 9.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for scikit-surprise (setup.py) ... done

# %%
import pandas as pd
import numpy as np
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise import accuracy
import convokit

# %%
#Downloading and Loading the Cornell Movie Dialogs Corpus
crps = convokit.Corpus(filename=convokit.download("movie-corpus"))
# Out:
# Downloading movie-corpus to /root/.convokit/downloads/movie-corpus
# Downloading movie-corpus from http://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip (40.9MB)... Done

# %%
# Display basic statistics
print("Number of conversations:", len(crps.conversations))
print("Number of users:", len(crps.speakers))
print("Number of utterances:", len(crps.utterances))
# Out:
# Number of conversations: 83097
# Number of users: 9035
# Number of utterances: 304713

# %%
# Display information about conversations
for convo_id in crps.get_conversation_ids():
    convo = crps.get_conversation(convo_id)
    print("Conversation ID:", convo_id)
    print("Metadata:", convo.meta)
    print("Number of utterances in conversation:", len(convo.get_utterance_ids()))
    print()
# Out:
# Streaming output truncated to the last 5000 lines.
# Number of utterances in conversation: 2
#
# Conversation ID: L257689
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257621
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257597
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L257581
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L257547
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L257489
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257487
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257485
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257482
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L257478
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257468
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L257466
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257694
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 10
#
# Conversation ID: L257687
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257636
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L257632
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L257630
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257563
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257556
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L257408
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L257401
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L257393
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L257839
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L257814
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257806
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L257749
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257743
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L257737
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257731
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257725
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257603
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 10
#
# Conversation ID: L257442
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257439
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L257435
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L257429
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L257425
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L257423
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257421
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257660
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257657
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L257654
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L257645
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L257625
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257515
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L257508
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L257716
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L257664
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L257816
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L257791
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L257754
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L257751
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L257740
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L257733
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L257727
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L257616
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L257542
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L257532
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L257527
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L257781
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L257623
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257774
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L257763
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 11
#
# Conversation ID: L257710
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L257678
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257627
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257506
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257493
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L257491
# Metadata: ConvoKitMeta({'movie_idx': 'm80', 'movie_name': 'halloween h20: 20 years later', 'release_year': '1998', 'rating': '5.40', 'votes': '22353', 'genre': "['drama', 'horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261197
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L260948
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L260937
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L261192
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L261190
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261188
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261163
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L261082
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L260958
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L260945
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L260940
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261273
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261181
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L261101
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261096
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L260834
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L260826
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L260818
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261051
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L261049
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L260916
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L260913
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L261041
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L261031
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L261022
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L260960
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L260890
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L260888
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261279
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261277
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261231
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261221
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261131
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261128
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261124
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L261110
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261107
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L261104
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261099
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261073
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L261070
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261269
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L261255
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261239
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 11
#
# Conversation ID: L261237
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261092
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261086
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L261018
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L260995
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L260973
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L260910
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L260902
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L260886
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L260878
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L260871
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L260867
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261228
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261223
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L261011
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L261009
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261005
# Metadata: ConvoKitMeta({'movie_idx': 'm81', 'movie_name': 'halloween: the curse of michael myers', 'release_year': '1995', 'rating': '4.50', 'votes': '8743', 'genre': "['horror', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L268127
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 24
#
# Conversation ID: L268089
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L268063
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L268050
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L268041
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L268019
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L267935
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 14
#
# Conversation ID: L267929
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L267925
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L267896
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L267882
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L267874
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L267867
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L267500
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L267476
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 23
#
# Conversation ID: L267459
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 17
#
# Conversation ID: L267457
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L267447
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 10
#
# Conversation ID: L267444
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L267434
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 10
#
# Conversation ID: L268154
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 24
#
# Conversation ID: L268123
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L268114
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L268081
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L268079
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L268076
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L268056
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L268044
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L268029
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L268249
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L268237
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L268214
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L268207
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L268205
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L268086
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L268052
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L267912
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L267859
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L267841
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L267837
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L267753
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L267731
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 18
#
# Conversation ID: L267682
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L267613
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 18
#
# Conversation ID: L267558
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 54
#
# Conversation ID: L267542
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 16
#
# Conversation ID: L267535
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L268316
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L268313
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L268308
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L268303
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L268299
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L268297
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L268290
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L268280
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L268270
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L268262
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L268246
# Metadata: ConvoKitMeta({'movie_idx': 'm82', 'movie_name': 'happy birthday, wanda june', 'release_year': '1971', 'rating': '5.80', 'votes': '144', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# ...
# Number of utterances in conversation: 6
#
# Conversation ID: L666019
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665957
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665904
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665896
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665891
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665873
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665868
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665865
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665861
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665840
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665802
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665798
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665775
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665755
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665748
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L665691
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665676
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665663
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665658
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665636
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665627
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L665623
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665615
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L665564
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665558
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665552
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665548
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666168
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666166
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666160
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666158
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666151
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L666149
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665949
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665900
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665885
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665694
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665651
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665994
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665992
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665987
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L666462
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666365
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666361
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666503
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666388
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 11
#
# Conversation ID: L666487
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666483
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666480
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666357
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666249
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666246
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666546
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666485
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666460
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666383
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666251
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666497
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L666575
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666324
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666262
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666520
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666369
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666256
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2

# %%
# Create empty lists to store data
conversation_ids = []
movie_indices = []
movie_names = []
release_years = []
ratings = []
votes = []
genres = []
num_utterances = []

# Loop through conversations and extract data
for convo_id in crps.get_conversation_ids():
    convo = crps.get_conversation(convo_id)

    # Extract metadata from ConvoKitMeta object
    metadata = convo.meta

    # Append data to respective lists
    conversation_ids.append(convo_id)
    movie_indices.append(metadata['movie_idx'])
    movie_names.append(metadata['movie_name'])
    release_years.append(metadata['release_year'])
    ratings.append(metadata['rating'])
    votes.append(metadata['votes'])
    genres.append(metadata['genre'])
    num_utterances.append(len(convo.get_utterance_ids()))

# Create a DataFrame from the lists
data = {
    'Conversation ID': conversation_ids,
    'Movie Index': movie_indices,
    'Movie Name': movie_names,
    'Rating': ratings,
}

df = pd.DataFrame(data)

# %%
#view the dataframe
df
# Out:
#       Conversation ID Movie Index                  Movie Name Rating
# 0               L1044          m0  10 things i hate about you   6.90
# 1                L984          m0  10 things i hate about you   6.90
# 2                L924          m0  10 things i hate about you   6.90
# 3                L870          m0  10 things i hate about you   6.90
# 4                L866          m0  10 things i hate about you   6.90
# ...               ...         ...                         ...    ...
# 83092         L666324        m616                   zulu dawn   6.40
# 83093         L666262        m616                   zulu dawn   6.40
# 83094         L666520        m616                   zulu dawn   6.40
# 83095         L666369        m616                   zulu dawn   6.40
# 83096         L666256        m616                   zulu dawn   6.40
#
# [83097 rows x 4 columns]

# %%
# Create a Reader object specifying the rating scale
reader = Reader(rating_scale=(1, 10))

# %%
# Load the dataset into Surprise format
data = df[['Conversation ID','Movie Name','Rating']]
data = Dataset.load_from_df(data, reader)

# Split the data into training and testing sets (80% train, 20% test)
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

# Create and train the SVD recommendation model
model = SVD()
model.fit(trainset)

# Evaluate the model on the testing data (calculate RMSE)
predictions = model.test(testset)
rmse = accuracy.rmse(predictions)
# Out:
# RMSE: 0.0636

# %%
# Generate recommendations for a specific user (e.g., user_id='L236416')
user_id = 'L36547'
user_movies = df[df['Conversation ID'] == user_id]['Movie Name'].unique()

# Create a list of unrated movies for the user
all_movies = df['Movie Name'].unique()
unrated_movies = np.setdiff1d(all_movies, user_movies)

# Generate predictions for unrated movies
user_recommendations = []
for movie_id in unrated_movies:
    predicted_rating = model.predict(user_id, movie_id).est
    user_recommendations.append((movie_id, predicted_rating))

    # Sort recommendations by predicted rating (highest first)
user_recommendations.sort(key=lambda x: x[1], reverse=True)

# %%
# Display the top n recommendations
top_n = 5
print(f'Top {top_n} recommendations for user {user_id}:')
for movie_id, predicted_rating in user_recommendations[:top_n]:
    print(f'Movie ID: {movie_id}, Predicted Rating: {predicted_rating:.2f}')
# Out:
# Top 5 recommendations for user L36547:
# Movie ID: neuromancer, Predicted Rating: 9.13
# Movie ID: the godfather, Predicted Rating: 9.12
# Movie ID: one flew over the cuckoo's nest, Predicted Rating: 8.92
# Movie ID: the godfather: part ii, Predicted Rating: 8.87
# Movie ID: fight club, Predicted Rating: 8.85
